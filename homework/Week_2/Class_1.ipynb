# %% [markdown]
# 1.-Given the Follwing Figure:
#
# <img src="Figure_WKS_Programming.png" style="width:70%;">
#
#
# Create the adjacent matrix. The number indicates the node ID number.
#
# This can be done either as a list, dataframe, np.array. Whatever you want.
#
# AI can do it in seconds, Do it yourself. Understand the concept.

# %% [markdown]
# Find the coordinates of every airpot  and save it in a logical way to access them.

# %% [markdown]
# How would you model a Flight AMS - IST - FCO using the Adjacent Matrix?
# Compute the total flight distance using this model and your adjacent Matrix.

# %% [markdown]
# How would yo model a flight AMS - PRG - MXP - FCO  using the Adjacent Matrix?
# Compute the total flight distance using this model and your adjacent Matrix.

# %% [markdown]
# Now, Create an Adjacent List

# %% [markdown]
# How would you model the Flight AMS - FRA - MXP - FCO using the Adjacent List?
# Compute the total flight distance using this model and your adjacent List.

# %% [markdown]
# Imagine you are at PRG. Now you want to visit PRG - VCE - FCO. How would you model this?
# Compute the total flight distance using this model and your adjacent Matrix or List.
